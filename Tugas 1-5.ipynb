# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 22)
#Tugas 1
df = pd.read_excel(r"C:\CO2Emission.xlsx")
df
# Out:
#           Country  Year  \
# 0     Afghanistan  1990
# 1     Afghanistan  1991
# 2     Afghanistan  1992
# 3     Afghanistan  1993
# 4     Afghanistan  1994
# ...           ...   ...
# 4319     Zimbabwe  2008
# 4320     Zimbabwe  2009
# 4321     Zimbabwe  2010
# 4322     Zimbabwe  2011
# 4323     Zimbabwe  2012
#
#       Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 0                                               15.2969
# 1                                               15.3514
# 2                                               14.0513
# 3                                               14.0649
# 4                                               14.0222
# ...                                                 ...
# 4319                                            23.0814
# 4320                                            24.0993
# 4321                                            24.9543
# 4322                                            25.9958
# ...

# %%
#Tugas 3
df.shape
# Out:
# (4324, 22)

# %%
#Tugas 4
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 22 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Country                                                               4324 non-null   object
#  1   Year                                                                  4324 non-null   int64
#  2   Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)   4218 non-null   float64
#  3   Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)  4218 non-null   float64
#  4   Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)            4304 non-null   float64
#  5   Total CH4 (MtCO2e)                                                    4220 non-null   float64
# ...

# %%
#Tugas 4
df.describe()
# Out:
#               Year  \
# count  4324.000000
# mean   2001.000000
# std       6.634017
# min    1990.000000
# 25%    1995.000000
# 50%    2001.000000
# 75%    2007.000000
# max    2012.000000
#
#        Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# count                                        4218.000000
# mean                                          429.346316
# std                                          2782.731453
# min                                             0.030500
# 25%                                             7.071550
# 50%                                            26.574650
# 75%                                           106.489325
# max                                         44815.535139
#
#        Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)  \
# count                                        4218.000000
# mean                                          458.518569
# ...

# %%
#Tugas 4
df.isna().sum()
# Out:
# Country                                                                    0
# Year                                                                       0
# Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)      106
# Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)     106
# Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)                20
# Total CH4 (MtCO2e)                                                       104
# Total N2O (MtCO2e)                                                       103
# Total F-Gas (MtCO2e)                                                       0
# Total CO2 (including Land-Use Change and Forestry) (MtCO2)               103
# Total CH4 (including Land-Use Change and Forestry) (MtCO2e)              241
# Total N2O (including Land-Use Change and Forestry) (MtCO2e)              241
# Energy (MtCO2e)                                                         1173
# ...

# %%
#Tugas 4
df.isna().mean().mul(100)
# Out:
# Country                                                                  0.000000
# Year                                                                     0.000000
# Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)      2.451434
# Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)     2.451434
# Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)               0.462535
# Total CH4 (MtCO2e)                                                       2.405180
# Total N2O (MtCO2e)                                                       2.382054
# Total F-Gas (MtCO2e)                                                     0.000000
# Total CO2 (including Land-Use Change and Forestry) (MtCO2)               2.382054
# Total CH4 (including Land-Use Change and Forestry) (MtCO2e)              5.573543
# Total N2O (including Land-Use Change and Forestry) (MtCO2e)              5.573543
# ...

# %%
#Tugas 5
df.head(10)
# Out:
#        Country  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
# 5  Afghanistan  1995
# 6  Afghanistan  1996
# 7  Afghanistan  1997
# 8  Afghanistan  1998
# 9  Afghanistan  1999
#
#    Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 0                                            15.2969
# 1                                            15.3514
# 2                                            14.0513
# 3                                            14.0649
# 4                                            14.0222
# 5                                            14.3679
# 6                                            15.3510
# 7                                            16.3108
# 8                                            17.1511
# 9                                            18.0201
#
#    Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)  \
# ...

# %%
#Tugas 5
df.tail(10)
# Out:
#        Country  Year  \
# 4314  Zimbabwe  2003
# 4315  Zimbabwe  2004
# 4316  Zimbabwe  2005
# 4317  Zimbabwe  2006
# 4318  Zimbabwe  2007
# 4319  Zimbabwe  2008
# 4320  Zimbabwe  2009
# 4321  Zimbabwe  2010
# 4322  Zimbabwe  2011
# 4323  Zimbabwe  2012
#
#       Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 4314                                            24.6692
# 4315                                            24.8346
# 4316                                            24.8613
# 4317                                            24.4569
# 4318                                            24.6141
# 4319                                            23.0814
# 4320                                            24.0993
# 4321                                            24.9543
# 4322                                            25.9958
# 4323                                            25.2187
#
#       Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)  \
# ...

# %%
df1 = df["Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)"]
df1
df1.min()
df1.max()
df1.describe()
# Out:
# count     4218.000000
# mean       429.346316
# std       2782.731453
# min          0.030500
# 25%          7.071550
# 50%         26.574650
# 75%        106.489325
# max      44815.535139
# Name: Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e), dtype: float64

# %%
#Tugas 5
df2 = df["Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)"]
df2
df2.min()
df2.max()
df2.describe()
# Out:
# count     4218.000000
# mean       458.518569
# std       2977.703357
# min       -139.274000
# 25%          8.588075
# 50%         38.805950
# 75%        134.983125
# max      47598.554159
# Name: Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍), dtype: float64

# %%
#Tugas 5
df.describe()
# Out:
#               Year  \
# count  4324.000000
# mean   2001.000000
# std       6.634017
# min    1990.000000
# 25%    1995.000000
# 50%    2001.000000
# 75%    2007.000000
# max    2012.000000
#
#        Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# count                                        4218.000000
# mean                                          429.346316
# std                                          2782.731453
# min                                             0.030500
# 25%                                             7.071550
# 50%                                            26.574650
# 75%                                           106.489325
# max                                         44815.535139
#
#        Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)  \
# count                                        4218.000000
# mean                                          458.518569
# ...

# %%
#Tugas 5
df.max()
# Out:
# Country                                                                 Zimbabwe
# Year                                                                        2012
# Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)      44815.5
# Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)     47598.6
# Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)                 33843
# Total CH4 (MtCO2e)                                                       7153.96
# Total N2O (MtCO2e)                                                       3045.42
# Total F-Gas (MtCO2e)                                                     773.106
# Total CO2 (including Land-Use Change and Forestry) (MtCO2)               36421.8
# Total CH4 (including Land-Use Change and Forestry) (MtCO2e)               7298.6
# Total N2O (including Land-Use Change and Forestry) (MtCO2e)              3105.04
# Energy (MtCO2e)                                                          35099.1
# ...

# %%
#Tugas 5
df.min()
# Out:
# Country                                                                 Afghanistan
# Year                                                                           1990
# Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)          0.0305
# Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)       -139.274
# Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)                        0
# Total CH4 (MtCO2e)                                                           0.0029
# Total N2O (MtCO2e)                                                           0.0005
# Total F-Gas (MtCO2e)                                                              0
# Total CO2 (including Land-Use Change and Forestry) (MtCO2)                 -187.311
# Total CH4 (including Land-Use Change and Forestry) (MtCO2e)               0.0107008
# Total N2O (including Land-Use Change and Forestry) (MtCO2e)             0.000516975
# ...
