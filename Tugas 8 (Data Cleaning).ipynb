# %%
#Tugas 8

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 22)
df = pd.read_excel(r"C:\CO2Emission.xlsx")

# %%
#Cek jumlah baris dan kolom pada awal data
df.shape
# Out:
# (4324, 22)

# %%
#cek presentase data kosong
df.isnull().mean().mul(100)
# Out:
# Country                                                                  0.000000
# Year                                                                     0.000000
# Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)      2.451434
# Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)     2.451434
# Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)               0.462535
# Total CH4 (MtCO2e)                                                       2.405180
# Total N2O (MtCO2e)                                                       2.382054
# Total F-Gas (MtCO2e)                                                     0.000000
# Total CO2 (including Land-Use Change and Forestry) (MtCO2)               2.382054
# Total CH4 (including Land-Use Change and Forestry) (MtCO2e)              5.573543
# Total N2O (including Land-Use Change and Forestry) (MtCO2e)              5.573543
# ...

# %%
#Memberikan batas untuk data kosong yang ingin dibuang per baris
batas = 5 #Misal batas data yang kosong 5, lebih dari 5 maka akan di buang
df_semi_clean = df.dropna(thresh = 5, axis = "rows")

# %%
#Cek kembali jumlah baris dan kolom
df_semi_clean.shape
# Out:
# (4306, 22)

# %%
#Mengubah data negatif menjadi 0
df_clean_1 = df_semi_clean._get_numeric_data()
df_clean_1[df_clean_1 < 0] = 0

# %%
#Mengubah data kosong menjadi 0
df_clean_2 = df_clean_1.fillna(0)

# %%
#DataFrame sebelum dibersihkan
df.describe()
# Out:
#               Year  \
# count  4324.000000
# mean   2001.000000
# std       6.634017
# min    1990.000000
# 25%    1995.000000
# 50%    2001.000000
# 75%    2007.000000
# max    2012.000000
#
#        Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# count                                        4218.000000
# mean                                          429.346316
# std                                          2782.731453
# min                                             0.030500
# 25%                                             7.071550
# 50%                                            26.574650
# 75%                                           106.489325
# max                                         44815.535139
#
#        Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)  \
# count                                        4218.000000
# mean                                          458.518569
# ...

# %%
#DataFrame setelah dibersihkan
df_clean_2.describe()
# Out:
#               Year  \
# count  4306.000000
# mean   2001.021366
# std       6.632760
# min    1990.000000
# 25%    1995.000000
# 50%    2001.000000
# 75%    2007.000000
# max    2012.000000
#
#        Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# count                                        4306.000000
# mean                                          420.571937
# std                                          2754.813234
# min                                             0.000000
# 25%                                             6.375475
# 50%                                            25.324150
# 75%                                           100.910100
# max                                         44815.535139
#
#        Total GHG Emissions Including Land-Use Change and Forestry (MtCO₂e‍)  \
# count                                        4306.000000
# mean                                          449.433585
# ...
